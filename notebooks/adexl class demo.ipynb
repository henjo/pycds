# %%
import cds.adexl as adexl

datadir = "/home/hjohansson/pycds/cds/test/data/adexl"

# %%
adexl_result = adexl.ADE_XL_Result(datadir)

# %%
adexl_result.get_history_entry_names()
# Out:
# ['Interactive.205',
#  'Interactive.206',
#  'Interactive.207',
#  'Interactive.208',
#  'Interactive.209',
#  'Interactive.210',
#  'Interactive.211',
#  'Interactive.212',
#  'Interactive.213',
#  'Interactive.214',
#  'Interactive.215',
#  'Interactive.216',
#  'Interactive.217',
#  'Interactive.218',
#  'Interactive.219']

# %%
h_entry = adexl_result.get_history_entry('Interactive.210')

# %%
h_entry.get_all_results(adexl_result)
# Out:
#    name  pointID          name       value
# 0  psrr        1  PStoCM 20MHz  -15.293499
# 1  psrr        1  PStoDM 20MHz -165.119020
# 2  psrr        1  PStoDM 40MHz -159.372130
# 3  psrr        1  PStoDM 10MHz -170.331518
# 4  psrr        1  PStoCM 40MHz  -15.293499
# 5  psrr        1  PStoCM 10MHz  -15.293499

# %%
h_entry.get_parameters(1, adexl_result)
# Out:
#        name  value
# 0         C     1p
# 1     Cload   100f
# 2     Ibias    25u
# 3     Rload   400k
# 4       Vcm   650m
# 5    Vcmdac    0.6
# 6     Vcmin   0.65
# 7    Vcmout   0.65
# 8       Vdd   1.35
# 9       amp    10m
# 10     amp1    10m
# 11     amp2    10m
# 12       bw     37
# 13      dac      0
# 14      fin     1M
# 15     fund    10M
# 16    fund1    32M
# 17    fund2    36M
# 18     gain      7
# 19    gain1      1
# 20    gain2      1
# 21      iac  0.005
# 22     idac     1u
# 23      idc   2.5m
# 24      iin     1u
# 25   iin_ac      0
# 26  iin_amp      0
# 27   iin_dc      0
# 28  rc_proc      1
